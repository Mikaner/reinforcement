# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikaner/reinforcement/blob/main/PrioritizedExperienceReplay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq -y install libcusparse8.0 libnvrtc8.0 libnvtoolsext1 > /dev/null
# !ln -snf /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so.8.0 /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so
# !apt -qq install xvfb freeglut3-dev ffmpeg> /dev/null
# !pip -q install gym
# !pip -q install JSAnimation
# !pip -q install pyglet
# !pip -q install pyopengl
# !pip -q install pyvirtualdisplay
# Out:
# E: Unable to locate package libcusparse8.0
# E: Couldn't find any package by glob 'libcusparse8.0'
# E: Couldn't find any package by regex 'libcusparse8.0'
# E: Unable to locate package libnvrtc8.0
# E: Couldn't find any package by glob 'libnvrtc8.0'
# E: Couldn't find any package by regex 'libnvrtc8.0'
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#   Building wheel for JSAnimation (setup.py) ... done

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
os.environ["DISPLAY"] = f":{display.display}"
# https://github.com/ponty/PyVirtualDisplay/issues/54

# %%
# 動画の描画関数の宣言
# 参考URL: http://nbviewer.jupyter.org/github/patrickmineault/xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
#from IPython.display import display
from IPython.display import HTML

def make_anim(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), 
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])
    
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)
    return anim

def save_frames_as_gif(frames):
    """
    DISPLAYs a list of frames as a gif, with controls
    """
    
    anim = make_anim(frames)
    anim.save('movie_cartpole_DQN.mp4')
    #display(display_animation(anim, default_mode='loop'))
    return anim.to_jshtml()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# namedtupleを生成
from collections import namedtuple

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99
MAX_STEPS = 200
NUM_EPISODES = 500

# %%
# ミニバッチ学習を実現するために
# 経験を保存するメモリクラスを定義します

class ReplayMemory:
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0

    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)をメモリに保存する'''

        if len(self.memory) < self.capacity:
            self.memory.append(None) # メモリが満タンでないときは足す
            
        # namedtupleのTransitionを使用し、値とフィールド名をペアにして保存します
        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity # 保存するindexを1つずらす(最大の場合は最初に上書き)

    def sample(self, batch_size):
        '''batch_size分だけ、ランダムに保存内容を取り出す'''
        return random.sample(self.memory, batch_size)

    def __len__(self):
        '''関数lenに対して、現在の変数memoryの長さを返す'''
        return len(self.memory)

# %%
TD_ERROR_EPSILON = 0.0001

class TDerrorMemory:
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY # メモリの最大長さ
        self.memory = [] # 経験を保存する変数
        self.index = 0 # 保存するindexを示す変数

    def push(self, td_error):
        if len(self.memory) < self.capacity:
            self.memory.append(None) # メモリが満タンでないときは足す
        
        self.memory[self.index] = td_error
        self.index = (self.index + 1) % self.capacity # 保存するindexを1つずつずらす

    def __len__(self):
        '''関数lenに対して、現在の変数memoryの長さを返す'''
        return len(self.memory)

    def get_prioritized_indexes(self, batch_size):
        '''TD誤差に応じた確率でindexを取得'''

        # TD誤差の和を計算
        sum_absolute_td_error = np.sum(np.absolute(self.memory))
        sum_absolute_td_error += TD_ERROR_EPSILON * len(self.memory)

        # batch_size文の乱数を生成して、昇順に並べる
        rand_list = np.random.uniform(0, sum_absolute_td_error, batch_size)
        rand_list = np.sort(rand_list)

        # 作成した乱数で串刺しにして、インデックスを求める
        indexes = []
        idx = 0
        tmp_sum_absolute_td_error = 0
        for rand_num in rand_list:
            while tmp_sum_absolute_td_error < rand_num:
                tmp_sum_absolute_td_error += (
                    abs(self.memory[idx]) + TD_ERROR_EPSILON)
                idx += 1
            if idx >= len(self.memory):
                idx = len(self.memory) - 1
            indexes.append(idx)
        
        return indexes
    
    def update_td_error(self, updated_td_errors):
        '''TD誤差の更新'''
        self.memory = updated_td_errors

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        output = self.fc3(h2)
        return output

# %%
# エージェントが持つ脳となるクラス。DQNを実行する。
# Q関数をディープラーニングのネットワークをクラスとして定義

import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000  # メモリの最大値(メモリが足りなくなるなんてことがあるのかしら)


class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions # CartPoleの行動(右に左に押す)の2を取得

        # 経験を記憶するメモリオブジェクトを生成
        self.memory = ReplayMemory(CAPACITY)
        
        # ニューラルネットワークを構築
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)
        print(self.main_q_network)

        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)

        self.td_error_memory = TDerrorMemory(CAPACITY)

    def replay(self, episode):
        '''Experience Replayでネットワークの結合パラメータを学習'''

        # -------------------------------------------------
        # 1. メモリサイズの確認
        # -------------------------------------------------
        # 1.1 メモリサイズがミニバッチより小さい間は何もしない
        if len(self.memory) < BATCH_SIZE:
            return
        
        # -------------------------------------------------
        # 2. ミニバッチの作成
        # -------------------------------------------------
        # make_minibatchに関数化
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch(episode)
        

        # -------------------------------------------------
        # 3. 教師信号となるQ(s_t, a_t)値を求める
        # -------------------------------------------------
        # get_expected_state_action_valuesに関数化
        self.expected_state_action_values = self.get_expected_state_action_values()

        # -------------------------------------------------
        # 4. 結合パラメータの更新
        # -------------------------------------------------
        # update_main_q_networkに関数化
        self.update_main_q_network()

    def decide_action(self, state, episode):
        ''' 現在の状況に応じて、行動を決定する '''
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval() # ネットワークを推論モードに切り替える
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # ネットワークの出力の最大値のindexを取り出します = max(1)[1]
            # .view(1, 1)は[torch.LongTensor of size 1] を size 1x1 に変換します
        
        else:
            # 0, 1の行動をランダムに返す
            action = torch.LongTensor([[random.randrange(self.num_actions)]]) # 0, 1の行動をランダムに返す
            # actionは[torch.LongTensor of size 1x1]の形になります

        return action
    
    def make_minibatch(self, episode):
        '''ミニバッチの作成'''
        if episode < 30:
            transitions = self.memory.sample(BATCH_SIZE)
        else:
            # TD誤差に応じてミニバッチを取り出すに変更
            indexes = self.td_error_memory.get_prioritized_indexes(BATCH_SIZE)
            transitions = [self.memory.memory[n] for n in indexes]

        #print("transitions")
        #print(transitions)
        #print(*transitions)

        batch = Transition(*zip(*transitions)) #named_tuple
        #print("batch")
        #print(batch)

        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        self.main_q_network.eval()
        self.target_q_network.eval()

        # ネットワークが出力したQ(s_t, a_t)を求める
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)

        # CartPoleがdoneになっておらず、next_stateが存在するかチェックするインデックスマスク
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))
        # ByteTensorとは:　8-bit integer (unsigned)のテンソル行列
        # True or Falseの値になっているので、1か0の値に直される

        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        # 次の状態での最大Q値の行動a_mをMain Q-Networkから求める
        # 最後の[1]で行動に対応したindexが返る
        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]

        # 次の状態があるものだけフィルターし、size 32を32×1へ
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 次の状態があるindexの、行動a_mのQ値をtarget Q-Networkから求める
        # detach()で取り出す
        # squeeze()でsize[minibatch×1]を[minibatch]へ
        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        # 教師となるQ値を求めるQ学習の式
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):

        self.main_q_network.train()

        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_q_network(self):
        ''' target Q-Networkをmainと同じにする '''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

    def update_td_error_memory(self):
        '''TD誤差メモリに格納されているTD誤差を更新する'''

        # ネットワークを推論モードに切り替える
        self.main_q_network.eval()
        self.target_q_network.eval()

        # 全メモリでミニバッチを作成
        trainsitions = self.memory.memory
        batch = Transition(*zip(*trainsitions))

        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])

        # ネットワークが出力したQ(s_t, a_t)を求める
        state_action_values = self.main_q_network(state_batch).gather(1, action_batch)

        # cartpoleがdoneになっておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))

        # まずは全部0にしておく、サイズはメモリの長さである
        next_state_values = torch.zeros(len(self.memory))
        a_m = torch.zeros(len(self.memory)).type(torch.LongTensor)

        # 次の状態での最大Q値の行動a_mをMain Q-Networkから求める
        # 最後の[1]で行動に対応したindexが返る
        a_m[non_final_mask] = self.main_q_network(non_final_next_states).detach().max(1)[1]

        # 次の状態があるものだけにフィルターし、size 32を32x1へ
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 次の状態があるindexの、行動a_mのQ値をtarget Q-Networkから求める
        # detach()で取り出す
        # squeeze()でsize[minibatch×1]を[minibatch]に
        next_state_values[non_final_mask] = self.target_q_network(non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        # TD誤差を求める
        td_errors = (reward_batch + GAMMA * next_state_values) - state_action_values.squeeze()

        # TD誤差メモリを更新、Tensorをdetach()で取り出し、NumPyにしてから、Pythonのリストまで変換
        self.td_error_memory.memory = td_errors.detach().numpy().tolist()

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        '''課題の状態と行動の数を設定する'''
        self.brain = Brain(num_states, num_actions)
        # エージェントが行動を決定するための頭脳を生成

    def update_q_function(self, episode):
        '''Q関数を更新'''
        self.brain.replay(episode)

    def get_action(self, state, episode):
        '''行動を決定する'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memoryオブジェクトに、state, action, state_next, rewardの内容を保存する'''
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        '''target Q-Networkをmainと同じにする'''
        self.brain.update_target_q_network()

    def memorize_td_error(self, td_error):
        '''TD誤差メモリにTD誤差を格納'''
        self.brain.td_error_memory.push(td_error)
    
    def update_td_error_memory(self):
        '''TD誤差メモリに格納されているTD誤差を更新する'''
        self.brain.update_td_error_memory()

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV) # 実行する課題を設定
        self.num_states = self.env.observation_space.shape[0]
        # 課題の状態と行動の数を設定
        self.num_actions = self.env.action_space.n # CartPoleの行動（右に左に押す）の2を取得

        # 環境内で行動するAgentを設定
        self.agent = Agent(self.num_states, self.num_actions)

    def run(self):
        '''実行'''
        episode_10_list = np.zeros(10) # 10試行分の立ち続けたstep数を格納し、平均ステップ数を出力に利用

        complete_episodes = 0 # 195ステップ以上連続で立ち続けた試行数
        episode_final = False # 最後の試行フラグ
        frames = [] # 最後の試行を確認する動画用のフレーム

        for episode in range(NUM_EPISODES):
            observation = self.env.reset() # 環境の初期化

            state = observation # 観測をそのまま状態sとして使用
            state = torch.from_numpy(state).type(torch.FloatTensor) # numpy変数をPyTorchのテンソルに変換
            # FloatTensor of size 4をsize 1×4に変換
            state = torch.unsqueeze(state, 0)

            for step in range(MAX_STEPS):
                
                if episode_final or episode==NUM_EPISODES-1: # 最終試行ではframesに各時刻の画像を追加していく
                    frames.append(self.env.render(mode='rgb_array'))

                action = self.agent.get_action(state, episode) # 行動を求める
                #print(action)

                # 行動a_tの実行により、s_{t+1}とdoneフラグを求める
                # actionから.item()を指定して、中身を取り出す
                observation_next, _, done, _ = self.env.step(action.item()) # rewardとinfoは使わないので_

                # 報酬を与える。さらにepisodeの終了評価と、state_nextを設定する
                if done: # ステップ数が200経過するか、一定角度以上傾いた場合
                    state_next = None

                    # 直近10episodeの立てたstep数リストに追加
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor([-1.0]) # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0 # 連続性高記録をリセット
                    else:
                        reward = torch.FloatTensor([1.0]) # 立ったまま終了時は報酬1を与える

                        complete_episodes += 1
                else:
                    reward = torch.FloatTensor([0.0]) # 普段は報酬0
                    state_next = observation_next # 観測をそのまま状態とする
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor) # numpy変数をPyTorchのテンソルに変換
                    # FloatTensor of size 4 を size 1×4 に変換 ←ここ何やってんの？テンソルにした意味なに？
                    state_next = torch.unsqueeze(state_next, 0)
                    
                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)

                # TD誤差メモリにTD誤差を追加
                self.agent.memorize_td_error(0)

                # PrioritizedExperienceReplayでQ関数を更新する
                self.agent.update_q_function(episode)

                # 観測の更新
                state = state_next

                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps : 10試行の平均step数 = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    
                    # TD誤差メモリの中身を更新する
                    self.agent.update_td_error_memory()

                    # DDQN学習の際に追加。
                    # 2試行に1度Target Q-Networkをmainと同じにコピーする
                    if(episode % 2) == 0:
                        self.agent.update_target_q_function()
                    break

            if episode_final or episode==NUM_EPISODES-1:
                # 動画を保存
                anim = save_frames_as_gif(frames)
                return anim

            if complete_episodes >= 10:
                print('Ten consective success !!')
                episode_final = True

# %%
cartpole_env = Environment()
anim = cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 14 steps : 10試行の平均step数 = 1.4
# 1 Episode: Finished after 10 steps : 10試行の平均step数 = 2.4
# 2 Episode: Finished after 11 steps : 10試行の平均step数 = 3.5
# 3 Episode: Finished after 10 steps : 10試行の平均step数 = 4.5
# 4 Episode: Finished after 9 steps : 10試行の平均step数 = 5.4
# 5 Episode: Finished after 10 steps : 10試行の平均step数 = 6.4
# 6 Episode: Finished after 10 steps : 10試行の平均step数 = 7.4
# 7 Episode: Finished after 13 steps : 10試行の平均step数 = 8.7
# 8 Episode: Finished after 11 steps : 10試行の平均step数 = 9.8
# 9 Episode: Finished after 11 steps : 10試行の平均step数 = 10.9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:178: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:181: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:186: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:124: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:129: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
# 10 Episode: Finished after 10 steps : 10試行の平均step数 = 10.5
# 11 Episode: Finished after 10 steps : 10試行の平均step数 = 10.5
# 12 Episode: Finished after 12 steps : 10試行の平均step数 = 10.6
# 13 Episode: Finished after 11 steps : 10試行の平均step数 = 10.7
# 14 Episode: Finished after 10 steps : 10試行の平均step数 = 10.8
# 15 Episode: Finished after 9 steps : 10試行の平均step数 = 10.7
# 16 Episode: Finished after 10 steps : 10試行の平均step数 = 10.7
# 17 Episode: Finished after 12 steps : 10試行の平均step数 = 10.6
# 18 Episode: Finished after 13 steps : 10試行の平均step数 = 10.8
# 19 Episode: Finished after 11 steps : 10試行の平均step数 = 10.8
# 20 Episode: Finished after 12 steps : 10試行の平均step数 = 11.0
# 21 Episode: Finished after 12 steps : 10試行の平均step数 = 11.2
# 22 Episode: Finished after 11 steps : 10試行の平均step数 = 11.1
# 23 Episode: Finished after 12 steps : 10試行の平均step数 = 11.2
# 24 Episode: Finished after 13 steps : 10試行の平均step数 = 11.5
# 25 Episode: Finished after 12 steps : 10試行の平均step数 = 11.8
# 26 Episode: Finished after 10 steps : 10試行の平均step数 = 11.8
# 27 Episode: Finished after 13 steps : 10試行の平均step数 = 11.9
# 28 Episode: Finished after 10 steps : 10試行の平均step数 = 11.6
# 29 Episode: Finished after 10 steps : 10試行の平均step数 = 11.5
# 30 Episode: Finished after 10 steps : 10試行の平均step数 = 11.3
# 31 Episode: Finished after 11 steps : 10試行の平均step数 = 11.2
# 32 Episode: Finished after 10 steps : 10試行の平均step数 = 11.1
# 33 Episode: Finished after 9 steps : 10試行の平均step数 = 10.8
# 34 Episode: Finished after 9 steps : 10試行の平均step数 = 10.4
# 35 Episode: Finished after 10 steps : 10試行の平均step数 = 10.2
# 36 Episode: Finished after 12 steps : 10試行の平均step数 = 10.4
# 37 Episode: Finished after 11 steps : 10試行の平均step数 = 10.2
# 38 Episode: Finished after 11 steps : 10試行の平均step数 = 10.3
# 39 Episode: Finished after 13 steps : 10試行の平均step数 = 10.6
# 40 Episode: Finished after 14 steps : 10試行の平均step数 = 11.0
# 41 Episode: Finished after 15 steps : 10試行の平均step数 = 11.4
# 42 Episode: Finished after 11 steps : 10試行の平均step数 = 11.5
# 43 Episode: Finished after 12 steps : 10試行の平均step数 = 11.8
# 44 Episode: Finished after 15 steps : 10試行の平均step数 = 12.4
# 45 Episode: Finished after 12 steps : 10試行の平均step数 = 12.6
# 46 Episode: Finished after 17 steps : 10試行の平均step数 = 13.1
# 47 Episode: Finished after 11 steps : 10試行の平均step数 = 13.1
# 48 Episode: Finished after 13 steps : 10試行の平均step数 = 13.3
# 49 Episode: Finished after 13 steps : 10試行の平均step数 = 13.3
# 50 Episode: Finished after 11 steps : 10試行の平均step数 = 13.0
# 51 Episode: Finished after 13 steps : 10試行の平均step数 = 12.8
# 52 Episode: Finished after 13 steps : 10試行の平均step数 = 13.0
# 53 Episode: Finished after 12 steps : 10試行の平均step数 = 13.0
# 54 Episode: Finished after 16 steps : 10試行の平均step数 = 13.1
# 55 Episode: Finished after 15 steps : 10試行の平均step数 = 13.4
# 56 Episode: Finished after 12 steps : 10試行の平均step数 = 12.9
# 57 Episode: Finished after 11 steps : 10試行の平均step数 = 12.9
# 58 Episode: Finished after 11 steps : 10試行の平均step数 = 12.7
# 59 Episode: Finished after 15 steps : 10試行の平均step数 = 12.9
# 60 Episode: Finished after 16 steps : 10試行の平均step数 = 13.4
# 61 Episode: Finished after 19 steps : 10試行の平均step数 = 14.0
# 62 Episode: Finished after 12 steps : 10試行の平均step数 = 13.9
# 63 Episode: Finished after 20 steps : 10試行の平均step数 = 14.7
# 64 Episode: Finished after 16 steps : 10試行の平均step数 = 14.7
# 65 Episode: Finished after 21 steps : 10試行の平均step数 = 15.3
# 66 Episode: Finished after 21 steps : 10試行の平均step数 = 16.2
# 67 Episode: Finished after 19 steps : 10試行の平均step数 = 17.0
# 68 Episode: Finished after 13 steps : 10試行の平均step数 = 17.2
# 69 Episode: Finished after 19 steps : 10試行の平均step数 = 17.6
# 70 Episode: Finished after 16 steps : 10試行の平均step数 = 17.6
# 71 Episode: Finished after 14 steps : 10試行の平均step数 = 17.1
# 72 Episode: Finished after 17 steps : 10試行の平均step数 = 17.6
# 73 Episode: Finished after 13 steps : 10試行の平均step数 = 16.9
# 74 Episode: Finished after 16 steps : 10試行の平均step数 = 16.9
# 75 Episode: Finished after 13 steps : 10試行の平均step数 = 16.1
# 76 Episode: Finished after 18 steps : 10試行の平均step数 = 15.8
# 77 Episode: Finished after 17 steps : 10試行の平均step数 = 15.6
# 78 Episode: Finished after 17 steps : 10試行の平均step数 = 16.0
# 79 Episode: Finished after 18 steps : 10試行の平均step数 = 15.9
# 80 Episode: Finished after 18 steps : 10試行の平均step数 = 16.1
# 81 Episode: Finished after 19 steps : 10試行の平均step数 = 16.6
# 82 Episode: Finished after 16 steps : 10試行の平均step数 = 16.5
# 83 Episode: Finished after 19 steps : 10試行の平均step数 = 17.1
# 84 Episode: Finished after 15 steps : 10試行の平均step数 = 17.0
# 85 Episode: Finished after 18 steps : 10試行の平均step数 = 17.5
# 86 Episode: Finished after 15 steps : 10試行の平均step数 = 17.2
# 87 Episode: Finished after 17 steps : 10試行の平均step数 = 17.2
# 88 Episode: Finished after 14 steps : 10試行の平均step数 = 16.9
# 89 Episode: Finished after 16 steps : 10試行の平均step数 = 16.7
# 90 Episode: Finished after 21 steps : 10試行の平均step数 = 17.0
# 91 Episode: Finished after 20 steps : 10試行の平均step数 = 17.1
# 92 Episode: Finished after 22 steps : 10試行の平均step数 = 17.7
# 93 Episode: Finished after 20 steps : 10試行の平均step数 = 17.8
# 94 Episode: Finished after 24 steps : 10試行の平均step数 = 18.7
# 95 Episode: Finished after 18 steps : 10試行の平均step数 = 18.7
# 96 Episode: Finished after 19 steps : 10試行の平均step数 = 19.1
# 97 Episode: Finished after 16 steps : 10試行の平均step数 = 19.0
# 98 Episode: Finished after 15 steps : 10試行の平均step数 = 19.1
# 99 Episode: Finished after 16 steps : 10試行の平均step数 = 19.1
# 100 Episode: Finished after 16 steps : 10試行の平均step数 = 18.6
# 101 Episode: Finished after 22 steps : 10試行の平均step数 = 18.8
# 102 Episode: Finished after 20 steps : 10試行の平均step数 = 18.6
# 103 Episode: Finished after 26 steps : 10試行の平均step数 = 19.2
# 104 Episode: Finished after 24 steps : 10試行の平均step数 = 19.2
# 105 Episode: Finished after 18 steps : 10試行の平均step数 = 19.2
# 106 Episode: Finished after 16 steps : 10試行の平均step数 = 18.9
# 107 Episode: Finished after 19 steps : 10試行の平均step数 = 19.2
# 108 Episode: Finished after 29 steps : 10試行の平均step数 = 20.6
# 109 Episode: Finished after 21 steps : 10試行の平均step数 = 21.1
# 110 Episode: Finished after 21 steps : 10試行の平均step数 = 21.6
# 111 Episode: Finished after 18 steps : 10試行の平均step数 = 21.2
# 112 Episode: Finished after 24 steps : 10試行の平均step数 = 21.6
# 113 Episode: Finished after 30 steps : 10試行の平均step数 = 22.0
# 114 Episode: Finished after 24 steps : 10試行の平均step数 = 22.0
# 115 Episode: Finished after 41 steps : 10試行の平均step数 = 24.3
# 116 Episode: Finished after 31 steps : 10試行の平均step数 = 25.8
# 117 Episode: Finished after 31 steps : 10試行の平均step数 = 27.0
# 118 Episode: Finished after 27 steps : 10試行の平均step数 = 26.8
# 119 Episode: Finished after 28 steps : 10試行の平均step数 = 27.5
# 120 Episode: Finished after 34 steps : 10試行の平均step数 = 28.8
# 121 Episode: Finished after 34 steps : 10試行の平均step数 = 30.4
# 122 Episode: Finished after 46 steps : 10試行の平均step数 = 32.6
# 123 Episode: Finished after 44 steps : 10試行の平均step数 = 34.0
# 124 Episode: Finished after 99 steps : 10試行の平均step数 = 41.5
# 125 Episode: Finished after 35 steps : 10試行の平均step数 = 40.9
# 126 Episode: Finished after 33 steps : 10試行の平均step数 = 41.1
# 127 Episode: Finished after 79 steps : 10試行の平均step数 = 45.9
# 128 Episode: Finished after 25 steps : 10試行の平均step数 = 45.7
# 129 Episode: Finished after 43 steps : 10試行の平均step数 = 47.2
# 130 Episode: Finished after 62 steps : 10試行の平均step数 = 50.0
# 131 Episode: Finished after 200 steps : 10試行の平均step数 = 66.6
# 132 Episode: Finished after 71 steps : 10試行の平均step数 = 69.1
# 133 Episode: Finished after 65 steps : 10試行の平均step数 = 71.2
# 134 Episode: Finished after 55 steps : 10試行の平均step数 = 66.8
# 135 Episode: Finished after 74 steps : 10試行の平均step数 = 70.7
# 136 Episode: Finished after 70 steps : 10試行の平均step数 = 74.4
# 137 Episode: Finished after 77 steps : 10試行の平均step数 = 74.2
# 138 Episode: Finished after 84 steps : 10試行の平均step数 = 80.1
# 139 Episode: Finished after 109 steps : 10試行の平均step数 = 86.7
# 140 Episode: Finished after 121 steps : 10試行の平均step数 = 92.6
# 141 Episode: Finished after 75 steps : 10試行の平均step数 = 80.1
# 142 Episode: Finished after 57 steps : 10試行の平均step数 = 78.7
# 143 Episode: Finished after 68 steps : 10試行の平均step数 = 79.0
# 144 Episode: Finished after 83 steps : 10試行の平均step数 = 81.8
# 145 Episode: Finished after 61 steps : 10試行の平均step数 = 80.5
# 146 Episode: Finished after 90 steps : 10試行の平均step数 = 82.5
# 147 Episode: Finished after 77 steps : 10試行の平均step数 = 82.5
# 148 Episode: Finished after 193 steps : 10試行の平均step数 = 93.4
# 149 Episode: Finished after 200 steps : 10試行の平均step数 = 102.5
# 150 Episode: Finished after 105 steps : 10試行の平均step数 = 100.9
# 151 Episode: Finished after 156 steps : 10試行の平均step数 = 109.0
# 152 Episode: Finished after 107 steps : 10試行の平均step数 = 114.0
# 153 Episode: Finished after 192 steps : 10試行の平均step数 = 126.4
# 154 Episode: Finished after 195 steps : 10試行の平均step数 = 137.6
# 155 Episode: Finished after 104 steps : 10試行の平均step数 = 141.9
# 156 Episode: Finished after 96 steps : 10試行の平均step数 = 142.5
# 157 Episode: Finished after 123 steps : 10試行の平均step数 = 147.1
# 158 Episode: Finished after 144 steps : 10試行の平均step数 = 142.2
# 159 Episode: Finished after 116 steps : 10試行の平均step数 = 133.8
# 160 Episode: Finished after 117 steps : 10試行の平均step数 = 135.0
# 161 Episode: Finished after 152 steps : 10試行の平均step数 = 134.6
# 162 Episode: Finished after 150 steps : 10試行の平均step数 = 138.9
# 163 Episode: Finished after 114 steps : 10試行の平均step数 = 131.1
# 164 Episode: Finished after 157 steps : 10試行の平均step数 = 127.3
# 165 Episode: Finished after 146 steps : 10試行の平均step数 = 131.5
# 166 Episode: Finished after 116 steps : 10試行の平均step数 = 133.5
# 167 Episode: Finished after 121 steps : 10試行の平均step数 = 133.3
# 168 Episode: Finished after 90 steps : 10試行の平均step数 = 127.9
# 169 Episode: Finished after 108 steps : 10試行の平均step数 = 127.1
# 170 Episode: Finished after 86 steps : 10試行の平均step数 = 124.0
# 171 Episode: Finished after 140 steps : 10試行の平均step数 = 122.8
# 172 Episode: Finished after 95 steps : 10試行の平均step数 = 117.3
# 173 Episode: Finished after 142 steps : 10試行の平均step数 = 120.1
# 174 Episode: Finished after 99 steps : 10試行の平均step数 = 114.3
# 175 Episode: Finished after 115 steps : 10試行の平均step数 = 111.2
# 176 Episode: Finished after 90 steps : 10試行の平均step数 = 108.6
# 177 Episode: Finished after 88 steps : 10試行の平均step数 = 105.3
# 178 Episode: Finished after 97 steps : 10試行の平均step数 = 106.0
# 179 Episode: Finished after 153 steps : 10試行の平均step数 = 110.5
# 180 Episode: Finished after 97 steps : 10試行の平均step数 = 111.6
# 181 Episode: Finished after 105 steps : 10試行の平均step数 = 108.1
# 182 Episode: Finished after 101 steps : 10試行の平均step数 = 108.7
# 183 Episode: Finished after 103 steps : 10試行の平均step数 = 104.8
# 184 Episode: Finished after 116 steps : 10試行の平均step数 = 106.5
# 185 Episode: Finished after 86 steps : 10試行の平均step数 = 103.6
# 186 Episode: Finished after 110 steps : 10試行の平均step数 = 105.6
# 187 Episode: Finished after 113 steps : 10試行の平均step数 = 108.1
# 188 Episode: Finished after 111 steps : 10試行の平均step数 = 109.5
# 189 Episode: Finished after 150 steps : 10試行の平均step数 = 109.2
# 190 Episode: Finished after 118 steps : 10試行の平均step数 = 111.3
# 191 Episode: Finished after 102 steps : 10試行の平均step数 = 111.0
# 192 Episode: Finished after 116 steps : 10試行の平均step数 = 112.5
# 193 Episode: Finished after 150 steps : 10試行の平均step数 = 117.2
# 194 Episode: Finished after 94 steps : 10試行の平均step数 = 115.0
# 195 Episode: Finished after 144 steps : 10試行の平均step数 = 120.8
# 196 Episode: Finished after 121 steps : 10試行の平均step数 = 121.9
# 197 Episode: Finished after 190 steps : 10試行の平均step数 = 129.6
# 198 Episode: Finished after 99 steps : 10試行の平均step数 = 128.4
# 199 Episode: Finished after 143 steps : 10試行の平均step数 = 127.7
# 200 Episode: Finished after 103 steps : 10試行の平均step数 = 126.2
# 201 Episode: Finished after 115 steps : 10試行の平均step数 = 127.5
# 202 Episode: Finished after 123 steps : 10試行の平均step数 = 128.2
# 203 Episode: Finished after 124 steps : 10試行の平均step数 = 125.6
# 204 Episode: Finished after 116 steps : 10試行の平均step数 = 127.8
# 205 Episode: Finished after 121 steps : 10試行の平均step数 = 125.5
# 206 Episode: Finished after 138 steps : 10試行の平均step数 = 127.2
# 207 Episode: Finished after 158 steps : 10試行の平均step数 = 124.0
# 208 Episode: Finished after 142 steps : 10試行の平均step数 = 128.3
# 209 Episode: Finished after 155 steps : 10試行の平均step数 = 129.5
# 210 Episode: Finished after 164 steps : 10試行の平均step数 = 135.6
# 211 Episode: Finished after 138 steps : 10試行の平均step数 = 137.9
# 212 Episode: Finished after 140 steps : 10試行の平均step数 = 139.6
# 213 Episode: Finished after 132 steps : 10試行の平均step数 = 140.4
# 214 Episode: Finished after 156 steps : 10試行の平均step数 = 144.4
# 215 Episode: Finished after 110 steps : 10試行の平均step数 = 143.3
# 216 Episode: Finished after 119 steps : 10試行の平均step数 = 141.4
# 217 Episode: Finished after 157 steps : 10試行の平均step数 = 141.3
# 218 Episode: Finished after 115 steps : 10試行の平均step数 = 138.6
# 219 Episode: Finished after 159 steps : 10試行の平均step数 = 139.0
# 220 Episode: Finished after 128 steps : 10試行の平均step数 = 135.4
# 221 Episode: Finished after 138 steps : 10試行の平均step数 = 135.4
# 222 Episode: Finished after 159 steps : 10試行の平均step数 = 137.3
# 223 Episode: Finished after 153 steps : 10試行の平均step数 = 139.4
# 224 Episode: Finished after 173 steps : 10試行の平均step数 = 141.1
# 225 Episode: Finished after 133 steps : 10試行の平均step数 = 143.4
# 226 Episode: Finished after 149 steps : 10試行の平均step数 = 146.4
# 227 Episode: Finished after 151 steps : 10試行の平均step数 = 145.8
# 228 Episode: Finished after 160 steps : 10試行の平均step数 = 150.3
# 229 Episode: Finished after 155 steps : 10試行の平均step数 = 149.9
# 230 Episode: Finished after 162 steps : 10試行の平均step数 = 153.3
# 231 Episode: Finished after 159 steps : 10試行の平均step数 = 155.4
# 232 Episode: Finished after 161 steps : 10試行の平均step数 = 155.6
# 233 Episode: Finished after 158 steps : 10試行の平均step数 = 156.1
# 234 Episode: Finished after 149 steps : 10試行の平均step数 = 153.7
# 235 Episode: Finished after 128 steps : 10試行の平均step数 = 153.2
# 236 Episode: Finished after 158 steps : 10試行の平均step数 = 154.1
# 237 Episode: Finished after 173 steps : 10試行の平均step数 = 156.3
# 238 Episode: Finished after 191 steps : 10試行の平均step数 = 159.4
# 239 Episode: Finished after 179 steps : 10試行の平均step数 = 161.8
# 240 Episode: Finished after 143 steps : 10試行の平均step数 = 159.9
# 241 Episode: Finished after 183 steps : 10試行の平均step数 = 162.3
# 242 Episode: Finished after 133 steps : 10試行の平均step数 = 159.5
# 243 Episode: Finished after 137 steps : 10試行の平均step数 = 157.4
# 244 Episode: Finished after 150 steps : 10試行の平均step数 = 157.5
# 245 Episode: Finished after 156 steps : 10試行の平均step数 = 160.3
# 246 Episode: Finished after 155 steps : 10試行の平均step数 = 160.0
# 247 Episode: Finished after 127 steps : 10試行の平均step数 = 155.4
# 248 Episode: Finished after 200 steps : 10試行の平均step数 = 156.3
# 249 Episode: Finished after 143 steps : 10試行の平均step数 = 152.7
# 250 Episode: Finished after 135 steps : 10試行の平均step数 = 151.9
# 251 Episode: Finished after 160 steps : 10試行の平均step数 = 149.6
# 252 Episode: Finished after 200 steps : 10試行の平均step数 = 156.3
# 253 Episode: Finished after 160 steps : 10試行の平均step数 = 158.6
# 254 Episode: Finished after 183 steps : 10試行の平均step数 = 161.9
# 255 Episode: Finished after 141 steps : 10試行の平均step数 = 160.4
# 256 Episode: Finished after 140 steps : 10試行の平均step数 = 158.9
# 257 Episode: Finished after 194 steps : 10試行の平均step数 = 165.6
# 258 Episode: Finished after 182 steps : 10試行の平均step数 = 163.8
# 259 Episode: Finished after 172 steps : 10試行の平均step数 = 166.7
# 260 Episode: Finished after 167 steps : 10試行の平均step数 = 169.9
# 261 Episode: Finished after 146 steps : 10試行の平均step数 = 168.5
# 262 Episode: Finished after 158 steps : 10試行の平均step数 = 164.3
# 263 Episode: Finished after 164 steps : 10試行の平均step数 = 164.7
# 264 Episode: Finished after 151 steps : 10試行の平均step数 = 161.5
# 265 Episode: Finished after 200 steps : 10試行の平均step数 = 167.4
# 266 Episode: Finished after 158 steps : 10試行の平均step数 = 169.2
# 267 Episode: Finished after 148 steps : 10試行の平均step数 = 164.6
# 268 Episode: Finished after 151 steps : 10試行の平均step数 = 161.5
# 269 Episode: Finished after 190 steps : 10試行の平均step数 = 163.3
# 270 Episode: Finished after 166 steps : 10試行の平均step数 = 163.2
# 271 Episode: Finished after 200 steps : 10試行の平均step数 = 168.6
# 272 Episode: Finished after 157 steps : 10試行の平均step数 = 168.5
# 273 Episode: Finished after 149 steps : 10試行の平均step数 = 167.0
# 274 Episode: Finished after 189 steps : 10試行の平均step数 = 170.8
# 275 Episode: Finished after 165 steps : 10試行の平均step数 = 167.3
# 276 Episode: Finished after 150 steps : 10試行の平均step数 = 166.5
# 277 Episode: Finished after 170 steps : 10試行の平均step数 = 168.7
# 278 Episode: Finished after 195 steps : 10試行の平均step数 = 173.1
# 279 Episode: Finished after 171 steps : 10試行の平均step数 = 171.2
# 280 Episode: Finished after 169 steps : 10試行の平均step数 = 171.5
# 281 Episode: Finished after 200 steps : 10試行の平均step数 = 171.5
# 282 Episode: Finished after 169 steps : 10試行の平均step数 = 172.7
# 283 Episode: Finished after 200 steps : 10試行の平均step数 = 177.8
# 284 Episode: Finished after 145 steps : 10試行の平均step数 = 173.4
# 285 Episode: Finished after 156 steps : 10試行の平均step数 = 172.5
# 286 Episode: Finished after 192 steps : 10試行の平均step数 = 176.7
# 287 Episode: Finished after 200 steps : 10試行の平均step数 = 179.7
# 288 Episode: Finished after 200 steps : 10試行の平均step数 = 180.2
# 289 Episode: Finished after 185 steps : 10試行の平均step数 = 181.6
# 290 Episode: Finished after 200 steps : 10試行の平均step数 = 184.7
# 291 Episode: Finished after 200 steps : 10試行の平均step数 = 184.7
# 292 Episode: Finished after 200 steps : 10試行の平均step数 = 187.8
# 293 Episode: Finished after 200 steps : 10試行の平均step数 = 187.8
# 294 Episode: Finished after 200 steps : 10試行の平均step数 = 193.3
# 295 Episode: Finished after 200 steps : 10試行の平均step数 = 197.7
# 296 Episode: Finished after 200 steps : 10試行の平均step数 = 198.5
# 297 Episode: Finished after 200 steps : 10試行の平均step数 = 198.5
# 298 Episode: Finished after 200 steps : 10試行の平均step数 = 198.5
# 299 Episode: Finished after 200 steps : 10試行の平均step数 = 200.0
# Ten consective success !!
# 300 Episode: Finished after 200 steps : 10試行の平均step数 = 200.0

# %%
HTML(anim)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge93279f3e3434216968ac5b20e602e25">
#   <div class="anim-controls">
#     <input id="_anim_slidere93279f3e3434216968ac5b20e602e25" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime93279f3e3434216968ac5b20e602e25.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anime93279f3e3434216968ac5b20e602e25.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selecte93279f3e3434216968ac5b20e602e25" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e93279f3e3434216968ac5b20e602e25"
#              >
#       <label for="_anim_radio1_e93279f3e3434216968ac5b20e602e25">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e93279f3e3434216968ac5b20e602e25"
#              checked>
#       <label for="_anim_radio2_e93279f3e3434216968ac5b20e602e25">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e93279f3e3434216968ac5b20e602e25"
#              >
#       <label for="_anim_radio3_e93279f3e3434216968ac5b20e602e25">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge93279f3e3434216968ac5b20e602e25";
#     var slider_id = "_anim_slidere93279f3e3434216968ac5b20e602e25";
#     var loop_select_id = "_anim_loop_selecte93279f3e3434216968ac5b20e602e25";
#     var frames = new Array(200);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAJjklEQVR4nO3dwY+cdQHH4d/MbqECyS5pkBgTY1Bq\
# aiqQYIyYJt7qRdOLf4k3e+ihiYdePHow3j1g9tB4UG7+By4BdK0EzBoEQaHdgmvd3fHQ0AWxl+WT\
# vkz3eW7vTN4338tsPpmdd2a2WCwWAwCAzHzqAQAA9xuBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gA\
# ADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGB\
# BQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQ\
# E1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gA\
# ADGBBQAQE1gAADGBBQAQE1gAA
